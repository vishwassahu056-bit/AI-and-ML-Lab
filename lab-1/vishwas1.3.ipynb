# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([1, 3, 5, 7, 9])
b = np.array([2, 5, 6, 8, 10])

plt.plot(a, b, marker='.', color='c')
plt.show()

plt.bar(a, b)
plt.show()

plt.hist(b)
plt.show()

plt.pie(b)
plt.show()
